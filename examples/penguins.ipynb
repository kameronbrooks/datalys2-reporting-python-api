# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from dl2_reports import DL2Report

# %%
df = pd.read_csv("penguins_size.csv")

df = df.dropna()
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
# Test dataset with datetime columns (tz-aware + naive)
import pandas as pd

# tz-aware timestamps
when_utc = pd.date_range("2025-01-01 00:00:00", periods=5, freq="h", tz="UTC")
# naive timestamps (will be treated as UTC by DL2Report.add_df)
when_naive = pd.date_range("2025-01-01 00:00:00", periods=5, freq="h")

_df_dt = pd.DataFrame(
    {
        "when_utc": when_utc,
        "when_naive": when_naive,
        "value": [10, 20, 30, 40, 50],
    }
)

_dt_report = DL2Report(title="Datetime smoke test")
_dt_report.add_df("dt_iso", _df_dt.copy(), format="records", compress=False, timestamp_format="iso")
_dt_report.add_df("dt_epoch", _df_dt.copy(), format="records", compress=False, timestamp_format="epoch")

print("ISO sample:", _dt_report.datasets["dt_iso"]["data"][0])
print("Epoch sample:", _dt_report.datasets["dt_epoch"]["data"][0])

# show the DataFrame too
_df_dt
# Out:
# ISO sample: {'when_utc': '2025-01-01T00:00:00.000000Z', 'when_naive': '2025-01-01T00:00:00.000000Z', 'value': 10}
# Epoch sample: {'when_utc': 1735689600, 'when_naive': 1735689600, 'value': 10}
#                    when_utc          when_naive  value
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:00:00     10
# 1 2025-01-01 01:00:00+00:00 2025-01-01 01:00:00     20
# 2 2025-01-01 02:00:00+00:00 2025-01-01 02:00:00     30
# 3 2025-01-01 03:00:00+00:00 2025-01-01 03:00:00     40
# 4 2025-01-01 04:00:00+00:00 2025-01-01 04:00:00     50

# %%
# Render the datetime smoke-test as its own mini report (tables)
# Keeps it separate from the penguins report.

_dt_page = _dt_report.add_page("Datetime")

_dt_row = _dt_page.add_row()
_dt_row.add_table(dataset_id="dt_iso", title="Datetime (ISO)", pageSize=10)

_dt_row = _dt_page.add_row()
_dt_row.add_table(dataset_id="dt_epoch", title="Datetime (Epoch seconds)", pageSize=10)

_dt_report.save("datetime_smoke.html")
_dt_report.show()

_dt_report
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Datetime smoke test&lt;/title&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;&quot;&gt;
#     &lt;meta name=&quot;last-updated&quot; content=&quot;2025-12-29T13:17:53.655747&quot;&gt;
#
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/kameronbrooks/datalys2-reporting@latest/dist/dl2-style.css&quot;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#     &lt;script id=&quot;report-data&quot; type=&quot;application/json&quot;&gt;
# {
#     &quot;pages&quot;: [
#         {
#             &quot;title&quot;: &quot;Datetime&quot;,
#             &quot;rows&quot;: [
#                 {
#                     &quot;type&quot;: &quot;layout&quot;,
#                     &quot;direction&quot;: &quot;row&quot;,
#                     &quot;children&quot;: [
#                         {
#                             &quot;type&quot;: &quot;table&quot;,
#                             &quot;elementType&quot;: &quot;visual&quot;,
#                             &quot;datasetId&quot;: &quot;dt_iso&quot;,
#                             &quot;title&quot;: &quot;Datetime (ISO)&quot;,
#                             &quot;pageSize&quot;: 10
#                         }
#                     ]
#                 },
#                 {
#                     &quot;type&quot;: &quot;layout&quot;,
#                     &quot;direction&quot;: &quot;row&quot;,
#                     &quot;children&quot;: [
#                         {
#                             &quot;type&quot;: &quot;table&quot;,
#                             &quot;elementType&quot;: &quot;visual&quot;,
#                             &quot;datasetId&quot;: &quot;dt_epoch&quot;,
#                             &quot;title&quot;: &quot;Datetime (Epoch seconds)&quot;,
#                             &quot;pageSize&quot;: 10
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     &quot;datasets&quot;: {
#         &quot;dt_iso&quot;: {
#             &quot;id&quot;: &quot;dt_iso&quot;,
#             &quot;format&quot;: &quot;records&quot;,
#             &quot;columns&quot;: [
#                 &quot;when_utc&quot;,
#                 &quot;when_naive&quot;,
#                 &quot;value&quot;
#             ],
#             &quot;dtypes&quot;: [
#                 &quot;date&quot;,
#                 &quot;date&quot;,
#                 &quot;number&quot;
#             ],
#             &quot;data&quot;: [
#                 {
#                     &quot;when_utc&quot;: &quot;2025-01-01T00:00:00.000000Z&quot;,
#                     &quot;when_naive&quot;: &quot;2025-01-01T00:00:00.000000Z&quot;,
#                     &quot;value&quot;: 10
#                 },
#                 {
#                     &quot;when_utc&quot;: &quot;2025-01-01T01:00:00.000000Z&quot;,
#                     &quot;when_naive&quot;: &quot;2025-01-01T01:00:00.000000Z&quot;,
#                     &quot;value&quot;: 20
#                 },
#                 {
#                     &quot;when_utc&quot;: &quot;2025-01-01T02:00:00.000000Z&quot;,
#                     &quot;when_naive&quot;: &quot;2025-01-01T02:00:00.000000Z&quot;,
#                     &quot;value&quot;: 30
#                 },
#                 {
#                     &quot;when_utc&quot;: &quot;2025-01-01T03:00:00.000000Z&quot;,
#                     &quot;when_naive&quot;: &quot;2025-01-01T03:00:00.000000Z&quot;,
#                     &quot;value&quot;: 40
#                 },
#                 {
#                     &quot;when_utc&quot;: &quot;2025-01-01T04:00:00.000000Z&quot;,
#                     &quot;when_naive&quot;: &quot;2025-01-01T04:00:00.000000Z&quot;,
#                     &quot;value&quot;: 50
#                 }
#             ]
#         },
#         &quot;dt_epoch&quot;: {
#             &quot;id&quot;: &quot;dt_epoch&quot;,
#             &quot;format&quot;: &quot;records&quot;,
#             &quot;columns&quot;: [
#                 &quot;when_utc&quot;,
#                 &quot;when_naive&quot;,
#                 &quot;value&quot;
#             ],
#             &quot;dtypes&quot;: [
#                 &quot;date&quot;,
#                 &quot;date&quot;,
#                 &quot;number&quot;
#             ],
#             &quot;data&quot;: [
#                 {
#                     &quot;when_utc&quot;: 1735689600,
#                     &quot;when_naive&quot;: 1735689600,
#                     &quot;value&quot;: 10
#                 },
#                 {
#                     &quot;when_utc&quot;: 1735693200,
#                     &quot;when_naive&quot;: 1735693200,
#                     &quot;value&quot;: 20
#                 },
#                 {
#                     &quot;when_utc&quot;: 1735696800,
#                     &quot;when_naive&quot;: 1735696800,
#                     &quot;value&quot;: 30
#                 },
#                 {
#                     &quot;when_utc&quot;: 1735700400,
#                     &quot;when_naive&quot;: 1735700400,
#                     &quot;value&quot;: 40
#                 },
#                 {
#                     &quot;when_utc&quot;: 1735704000,
#                     &quot;when_naive&quot;: 1735704000,
#                     &quot;value&quot;: 50
#                 }
#             ]
#         }
#     }
# }
#     &lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/kameronbrooks/datalys2-reporting@latest/dist/datalys2-reports.min.js&quot;&gt;&lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;" width="100%" height="800px" style="border:none;"></iframe>

# %%
report = DL2Report(
    title="Pengins", 
    description="A report about penguin size. Based on data from https://www.kaggle.com/datasets/amulyas/penguin-size-dataset", 
    author="Kameron Brooks"
    )

report.add_df(
    "penguins", 
    df, 
    format="table", 
    compress=True
)

page = report.add_page("Main")

row = page.add_row()

vis1 = row.add_scatter(
    dataset_id="penguins", 
    x_column="flipper_length_mm", 
    y_column="body_mass_g", 
    xAxisLabel="Flipper Length", 
    yAxisLabel="Body Mass",
    title="Flipper vs Body Mass"
)
vis1.add_trend(coefficients=4, line_style="dashed", color="#FF5733")


vis2 = row.add_scatter(
    dataset_id="penguins", 
    x_column="culmen_length_mm", 
    y_column="body_mass_g", 
    xAxisLabel="Culmen Length", 
    yAxisLabel="Body Mass",
    title="Culmen vs Body Mass",
    showTrendline=True
)

row = page.add_row()
row.add_table(dataset_id="penguins", pageSize=20)

report.save("pengins.html")
report.show()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
report
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Pengins&lt;/title&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;A report about penguin size. Based on data from https://www.kaggle.com/datasets/amulyas/penguin-size-dataset&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Kameron Brooks&quot;&gt;
#     &lt;meta name=&quot;last-updated&quot; content=&quot;2025-12-25T04:56:26.850351&quot;&gt;
#     &lt;meta name=&quot;gc-compressed-data&quot; content=&quot;true&quot;&gt;
#
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/kameronbrooks/datalys2-reporting@latest/dist/dl2-style.css&quot;&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;script id=&quot;compressed-data-penguins&quot; type=&quot;text/b64-gzip&quot;&gt;...&lt;/script&gt;
#
#     &lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#     &lt;script id=&quot;report-data&quot; type=&quot;application/json&quot;&gt;
# {
#     &quot;pages&quot;: [
#         {
#             &quot;title&quot;: &quot;Main&quot;,
#             &quot;rows&quot;: [
#                 {
#                     &quot;type&quot;: &quot;layout&quot;,
#                     &quot;direction&quot;: &quot;row&quot;,
#                     &quot;children&quot;: [
#                         {
#                             &quot;type&quot;: &quot;scatter&quot;,
#                             &quot;elementType&quot;: &quot;visual&quot;,
#                             &quot;datasetId&quot;: &quot;penguins&quot;,
#                             &quot;otherElements&quot;: [
#                                 {
#                                     &quot;visualElementType&quot;: &quot;trend&quot;,
#                                     &quot;coefficients&quot;: [
#                                         177982.87419254362,
#                                         -2569.194046904498,
#                                         12.380811747235676,
#                                         -0.019416880418974842
#                                     ],
#                                     &quot;lineStyle&quot;: &quot;dashed&quot;,
#                                     &quot;lineColor&quot;: &quot;#FF5733&quot;
#                                 }
#                             ],
#                             &quot;xColumn&quot;: &quot;flipper_length_mm&quot;,
#                             &quot;yColumn&quot;: &quot;body_mass_g&quot;,
#                             &quot;xAxisLabel&quot;: &quot;Flipper Length&quot;,
#                             &quot;yAxisLabel&quot;: &quot;Body Mass&quot;,
#                             &quot;title&quot;: &quot;Flipper vs Body Mass&quot;
#                         },
#                         {
#                             &quot;type&quot;: &quot;scatter&quot;,
#                             &quot;elementType&quot;: &quot;visual&quot;,
#                             &quot;datasetId&quot;: &quot;penguins&quot;,
#                             &quot;xColumn&quot;: &quot;culmen_length_mm&quot;,
#                             &quot;yColumn&quot;: &quot;body_mass_g&quot;,
#                             &quot;xAxisLabel&quot;: &quot;Culmen Length&quot;,
#                             &quot;yAxisLabel&quot;: &quot;Body Mass&quot;,
#                             &quot;title&quot;: &quot;Culmen vs Body Mass&quot;,
#                             &quot;showTrendline&quot;: true
#                         }
#                     ]
#                 },
#                 {
#                     &quot;type&quot;: &quot;layout&quot;,
#                     &quot;direction&quot;: &quot;row&quot;,
#                     &quot;children&quot;: [
#                         {
#                             &quot;type&quot;: &quot;table&quot;,
#                             &quot;elementType&quot;: &quot;visual&quot;,
#                             &quot;datasetId&quot;: &quot;penguins&quot;,
#                             &quot;title&quot;: null,
#                             &quot;pageSize&quot;: 20
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     &quot;datasets&quot;: {
#         &quot;penguins&quot;: {
#             &quot;id&quot;: &quot;penguins&quot;,
#             &quot;format&quot;: &quot;table&quot;,
#             &quot;columns&quot;: [
#                 &quot;species&quot;,
#                 &quot;island&quot;,
#                 &quot;culmen_length_mm&quot;,
#                 &quot;culmen_depth_mm&quot;,
#                 &quot;flipper_length_mm&quot;,
#                 &quot;body_mass_g&quot;,
#                 &quot;sex&quot;
#             ],
#             &quot;dtypes&quot;: [
#                 &quot;string&quot;,
#                 &quot;string&quot;,
#                 &quot;number&quot;,
#                 &quot;number&quot;,
#                 &quot;number&quot;,
#                 &quot;number&quot;,
#                 &quot;string&quot;
#             ],
#             &quot;data&quot;: [],
#             &quot;compression&quot;: &quot;gzip&quot;,
#             &quot;compressedData&quot;: &quot;compressed-data-penguins&quot;
#         }
#     }
# }
#     &lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/kameronbrooks/datalys2-reporting@latest/dist/datalys2-reports.min.js&quot;&gt;&lt;/script&gt;
# &lt;/body&gt;
# &lt;/html&gt;" width="100%" height="800px" style="border:none;"></iframe>
