# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))
from dl2_reports import DL2Report

# %%
df = pd.read_csv("call_center_12mo.csv")

df = df.dropna()
df.head()
# Out:
#    call volume  email volume  asa(s)  abd rate   abd
# 0        28540          8120      42     0.038  1085
# 1        27110          7850      39     0.035   949
# 2        29875          8450      47     0.042  1255
# 3        31240          9025      52     0.047  1468
# 4        32690          9650      58     0.051  1667

# %%
report = DL2Report(
    title="Call center report", 
    description="A report about call center data. Based on data from call_center_12mo.csv", 
    author="Kameron Brooks"
    )

report.add_df(
    "call_center_data", 
    df, 
    format="table", 
    compress=True
)

page = report.add_page("Main")

row = page.add_row()
row.add_kpi(
    dataset_id="call_center_data",
    value_column="asa",
    row_index=-1,
    comparison_row_index=-2
)


row = page.add_row()
row.add_table(dataset_id="call_center_data", pageSize=20)

report.save("call_center_report.html")
report.show()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="data:text/html;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
report
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;&gt;
#     &lt;title&gt;Call center report&lt;/title&gt;
#     &lt;meta name=&quot;dl-version&quot; content=&quot;0.2.3&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;A report about call center data. Based on data from call_center_12mo.csv&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Kameron Brooks&quot;&gt;
#     &lt;meta name=&quot;last-updated&quot; content=&quot;01-13-2026 07:22:44&quot;&gt;
#     &lt;meta name=&quot;gc-compressed-data&quot; content=&quot;true&quot;&gt;
#
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/kameronbrooks/datalys2-reporting@latest/dist/dl2-style.css&quot;&gt;
# &lt;/head&gt;
# &lt;body&gt;
# ...
